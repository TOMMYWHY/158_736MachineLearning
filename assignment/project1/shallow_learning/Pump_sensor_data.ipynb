# %% [markdown]
# # Pump_sensor_data

# %%
#load the necessary modules
import pandas as pd
import numpy as np
from scipy.io import loadmat
import pickle
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import datetime
import os

# %%
path = '../ten-datasets/'

 
df_sensor = pd.read_csv(path + 'sensor.csv')
df_sensor.head()
# Y = df_forestdata.iloc[:,54]
# X = df_forestdata.iloc[:,0:54]
# train_data['X'][0]
# Out:
#    Unnamed: 0            timestamp  sensor_00  sensor_01  sensor_02  \
# 0           0  2018-04-01 00:00:00   2.465394   47.09201    53.2118
# 1           1  2018-04-01 00:01:00   2.465394   47.09201    53.2118
# 2           2  2018-04-01 00:02:00   2.444734   47.35243    53.2118
# 3           3  2018-04-01 00:03:00   2.460474   47.09201    53.1684
# 4           4  2018-04-01 00:04:00   2.445718   47.13541    53.2118
#
#    sensor_03  sensor_04  sensor_05  sensor_06  sensor_07  ...  sensor_43  \
# 0  46.310760   634.3750   76.45975   13.41146   16.13136  ...   41.92708
# 1  46.310760   634.3750   76.45975   13.41146   16.13136  ...   41.92708
# 2  46.397570   638.8889   73.54598   13.32465   16.03733  ...   41.66666
# 3  46.397568   628.1250   76.98898   13.31742   16.24711  ...   40.88541
# 4  46.397568   636.4583   76.58897   13.35359   16.21094  ...   41.40625
#
#    sensor_44  sensor_45  sensor_46  sensor_47  sensor_48  sensor_49  \
# ...

# %%
df_sensor['timestamp']
# datetime.datetime.fromtimestamp(df_sensor['timestamp'])
# Out:
# 0         2018-04-01 00:00:00
# 1         2018-04-01 00:01:00
# 2         2018-04-01 00:02:00
# 3         2018-04-01 00:03:00
# 4         2018-04-01 00:04:00
#                  ...
# 220315    2018-08-31 23:55:00
# 220316    2018-08-31 23:56:00
# 220317    2018-08-31 23:57:00
# 220318    2018-08-31 23:58:00
# 220319    2018-08-31 23:59:00
# Name: timestamp, Length: 220320, dtype: object

# %% [markdown]
# ## timestrap processing

# %%
temp=pd.DatetimeIndex(df_sensor['timestamp'])
df_sensor['date']=temp.date #添加date和time两个键和值
df_sensor['time']=temp.time

# %%
# df_sensor['hour']=pd.to_datetime(df_sensor.time,format="%H:%M:%S")#变换格式
# # df_sensor['hour']=pd.Index(df_sensor["hour"]).hour
# df_sensor['hour']

# %%
df_sensor.head()
# Out:
#    Unnamed: 0            timestamp  sensor_00  sensor_01  sensor_02  \
# 0           0  2018-04-01 00:00:00   2.465394   47.09201    53.2118
# 1           1  2018-04-01 00:01:00   2.465394   47.09201    53.2118
# 2           2  2018-04-01 00:02:00   2.444734   47.35243    53.2118
# 3           3  2018-04-01 00:03:00   2.460474   47.09201    53.1684
# 4           4  2018-04-01 00:04:00   2.445718   47.13541    53.2118
#
#    sensor_03  sensor_04  sensor_05  sensor_06  sensor_07  ...  sensor_45  \
# 0  46.310760   634.3750   76.45975   13.41146   16.13136  ...   65.68287
# 1  46.310760   634.3750   76.45975   13.41146   16.13136  ...   65.68287
# 2  46.397570   638.8889   73.54598   13.32465   16.03733  ...   65.39352
# 3  46.397568   628.1250   76.98898   13.31742   16.24711  ...   64.81481
# 4  46.397568   636.4583   76.58897   13.35359   16.21094  ...   65.10416
#
#    sensor_46  sensor_47  sensor_48  sensor_49  sensor_50  sensor_51  \
# ...

# %%
df_sensor['machine_status'].unique()
# Out:
# array(['NORMAL', 'BROKEN', 'RECOVERING'], dtype=object)

# %%
df_sensor["machine_status"]=df_sensor.machine_status.astype("category")
df_sensor.machine_status.dtype
# Out:
# CategoricalDtype(categories=['BROKEN', 'NORMAL', 'RECOVERING'], ordered=False)

# %%
df_sensor["machine_status"].cat.categories
df_sensor["machine_status_code"]=df_sensor["machine_status"].cat.codes
df_sensor["machine_status"].cat.codes.unique()
df_sensor
# Out:
#         Unnamed: 0        date      time  sensor_00  sensor_01  sensor_02  \
# 0                0  2018-04-01  00:00:00   2.465394   47.09201  53.211800
# 1                1  2018-04-01  00:01:00   2.465394   47.09201  53.211800
# 2                2  2018-04-01  00:02:00   2.444734   47.35243  53.211800
# 3                3  2018-04-01  00:03:00   2.460474   47.09201  53.168400
# 4                4  2018-04-01  00:04:00   2.445718   47.13541  53.211800
# ...            ...         ...       ...        ...        ...        ...
# 220315      220315  2018-08-31  23:55:00   2.407350   47.69965  50.520830
# 220316      220316  2018-08-31  23:56:00   2.400463   47.69965  50.564240
# 220317      220317  2018-08-31  23:57:00   2.396528   47.69965  50.520830
# 220318      220318  2018-08-31  23:58:00   2.406366   47.69965  50.520832
# 220319      220319  2018-08-31  23:59:00   2.396528   47.69965  50.520832
#
#         sensor_03   sensor_04  sensor_05  sensor_06  ...  sensor_44  \
# ...

# %%
df_sensor.columns
# Out:
# Index(['Unnamed: 0', 'timestamp', 'sensor_00', 'sensor_01', 'sensor_02',
#        'sensor_03', 'sensor_04', 'sensor_05', 'sensor_06', 'sensor_07',
#        'sensor_08', 'sensor_09', 'sensor_10', 'sensor_11', 'sensor_12',
#        'sensor_13', 'sensor_14', 'sensor_16', 'sensor_17', 'sensor_18',
#        'sensor_19', 'sensor_20', 'sensor_21', 'sensor_22', 'sensor_23',
#        'sensor_24', 'sensor_25', 'sensor_26', 'sensor_27', 'sensor_28',
#        'sensor_29', 'sensor_30', 'sensor_31', 'sensor_32', 'sensor_33',
#        'sensor_34', 'sensor_35', 'sensor_36', 'sensor_37', 'sensor_38',
#        'sensor_39', 'sensor_40', 'sensor_41', 'sensor_42', 'sensor_43',
#        'sensor_44', 'sensor_45', 'sensor_46', 'sensor_47', 'sensor_48',
#        'sensor_49', 'sensor_50', 'sensor_51', 'machine_status', 'date', 'time',
#        'machine_status_code'],
#       dtype='object')

# %%
len(df_sensor.columns)
# Out:
# 57

# %%
new_columns=  ['Unnamed: 0', 'date', 'time', 'sensor_00', 'sensor_01', 'sensor_02',
       'sensor_03', 'sensor_04', 'sensor_05', 'sensor_06', 'sensor_07',
       'sensor_08', 'sensor_09', 'sensor_10', 'sensor_11', 'sensor_12',
       'sensor_13', 'sensor_14', 'sensor_16', 'sensor_17', 'sensor_18',
       'sensor_19', 'sensor_20', 'sensor_21', 'sensor_22', 'sensor_23',
       'sensor_24', 'sensor_25', 'sensor_26', 'sensor_27', 'sensor_28',
       'sensor_29', 'sensor_30', 'sensor_31', 'sensor_32', 'sensor_33',
       'sensor_34', 'sensor_35', 'sensor_36', 'sensor_37', 'sensor_38',
       'sensor_39', 'sensor_40', 'sensor_41', 'sensor_42', 'sensor_43',
       'sensor_44', 'sensor_45', 'sensor_46', 'sensor_47', 'sensor_48',
       'sensor_49', 'sensor_50', 'sensor_51', 'machine_status', 
       'machine_status_code']

# %%
df_sensor = df_sensor[new_columns]

# %%
df_sensor.head()
# Out:
#    Unnamed: 0        date      time  sensor_00  sensor_01  sensor_02  \
# 0           0  2018-04-01  00:00:00   2.465394   47.09201    53.2118
# 1           1  2018-04-01  00:01:00   2.465394   47.09201    53.2118
# 2           2  2018-04-01  00:02:00   2.444734   47.35243    53.2118
# 3           3  2018-04-01  00:03:00   2.460474   47.09201    53.1684
# 4           4  2018-04-01  00:04:00   2.445718   47.13541    53.2118
#
#    sensor_03  sensor_04  sensor_05  sensor_06  ...  sensor_44  sensor_45  \
# 0  46.310760   634.3750   76.45975   13.41146  ...  39.641200   65.68287
# 1  46.310760   634.3750   76.45975   13.41146  ...  39.641200   65.68287
# 2  46.397570   638.8889   73.54598   13.32465  ...  39.351852   65.39352
# 3  46.397568   628.1250   76.98898   13.31742  ...  39.062500   64.81481
# 4  46.397568   636.4583   76.58897   13.35359  ...  38.773150   65.10416
#
#    sensor_46  sensor_47  sensor_48  sensor_49  sensor_50  sensor_51  \
# ...

# %%
df_sensor.info
# Out:
# <bound method DataFrame.info of         Unnamed: 0        date      time  sensor_00  sensor_01  sensor_02  \
# 0                0  2018-04-01  00:00:00   2.465394   47.09201  53.211800
# 1                1  2018-04-01  00:01:00   2.465394   47.09201  53.211800
# 2                2  2018-04-01  00:02:00   2.444734   47.35243  53.211800
# 3                3  2018-04-01  00:03:00   2.460474   47.09201  53.168400
# 4                4  2018-04-01  00:04:00   2.445718   47.13541  53.211800
# ...            ...         ...       ...        ...        ...        ...
# 220315      220315  2018-08-31  23:55:00   2.407350   47.69965  50.520830
# 220316      220316  2018-08-31  23:56:00   2.400463   47.69965  50.564240
# 220317      220317  2018-08-31  23:57:00   2.396528   47.69965  50.520830
# 220318      220318  2018-08-31  23:58:00   2.406366   47.69965  50.520832
# 220319      220319  2018-08-31  23:59:00   2.396528   47.69965  50.520832
#
# ...

# %%
y = df_sensor.iloc[:,-1]
print(y.shape)
X = df_sensor.iloc[:,0:-2]
print(X.shape)

X.head()
# Out:
# (220320,)
# (220320, 54)
#    Unnamed: 0        date      time  sensor_00  sensor_01  sensor_02  \
# 0           0  2018-04-01  00:00:00   2.465394   47.09201    53.2118
# 1           1  2018-04-01  00:01:00   2.465394   47.09201    53.2118
# 2           2  2018-04-01  00:02:00   2.444734   47.35243    53.2118
# 3           3  2018-04-01  00:03:00   2.460474   47.09201    53.1684
# 4           4  2018-04-01  00:04:00   2.445718   47.13541    53.2118
#
#    sensor_03  sensor_04  sensor_05  sensor_06  ...  sensor_42  sensor_43  \
# 0  46.310760   634.3750   76.45975   13.41146  ...  31.770832   41.92708
# 1  46.310760   634.3750   76.45975   13.41146  ...  31.770832   41.92708
# 2  46.397570   638.8889   73.54598   13.32465  ...  31.770830   41.66666
# 3  46.397568   628.1250   76.98898   13.31742  ...  31.510420   40.88541
# 4  46.397568   636.4583   76.58897   13.35359  ...  31.510420   41.40625
#
#    sensor_44  sensor_45  sensor_46  sensor_47  sensor_48  sensor_49  \
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size =0.2, random_state = 0, stratify=y)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (176256, 54)
# (176256,)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (44064, 54)
# (44064,)

# %% [markdown]
# ## logistic_regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

# %%
standardScaler = StandardScaler()
X_train_adv = standardScaler.fit_transform(X_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-132-38c5e472d8bf> in <module>
#       1 standardScaler = StandardScaler()
# ----> 2 X_train_adv = standardScaler.fit_transform(X_train)
#
# ~/opt/anaconda3/envs/python36/lib/python3.6/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     569         if y is None:
#     570             # fit method of arity 1 (unsupervised transformation)
# --> 571             return self.fit(X, **fit_params).transform(X)
#     572         else:
#     573             # fit method of arity 2 (supervised transformation)
#
# ~/opt/anaconda3/envs/python36/lib/python3.6/site-packages/sklearn/preprocessing/_data.py in fit(self, X, y)
#     667         # Reset internal state before fitting
#     668         self._reset()
# --> 669         return self.partial_fit(X, y)
#     670
# ...
