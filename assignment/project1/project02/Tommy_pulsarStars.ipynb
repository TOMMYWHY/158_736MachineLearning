# %% [markdown]
# # Predicting a Pulsar Star

# %%
#load the necessary modules
import pandas as pd
import numpy as np
# from scipy.io import loadmat
# import pickle
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns
import datetime
import os
import warnings
warnings.filterwarnings("ignore")

# %%
path = '../ten-datasets/'

#load the dataset into a dataframe
df = pd.read_csv(path + 'pulsar_stars.csv')

# %%
print(df.shape)
df.head()
# Out:
# (17898, 9)
#     Mean of the integrated profile  \
# 0                       140.562500
# 1                       102.507812
# 2                       103.015625
# 3                       136.750000
# 4                        88.726562
#
#     Standard deviation of the integrated profile  \
# 0                                      55.683782
# 1                                      58.882430
# 2                                      39.341649
# 3                                      57.178449
# 4                                      40.672225
#
#     Excess kurtosis of the integrated profile  \
# 0                                   -0.234571
# 1                                    0.465318
# 2                                    0.323328
# 3                                   -0.068415
# 4                                    0.600866
#
#     Skewness of the integrated profile   Mean of the DM-SNR curve  \
# 0                            -0.699648                   3.199833
# 1                            -0.515088                   1.677258
# 2                             1.051164                   3.121237
# 3                            -0.636238                   3.642977
# 4                             1.123492                   1.178930
#
#     Standard deviation of the DM-SNR curve  \
# 0                                19.110426
# 1                                14.860146
# 2                                21.744669
# 3                                20.959280
# 4                                11.468720
#
#     Excess kurtosis of the DM-SNR curve   Skewness of the DM-SNR curve  \
# 0                              7.975532                      74.242225
# 1                             10.576487                     127.393580
# 2                              7.735822                      63.171909
# 3                              6.896499                      53.593661
# 4                             14.269573                     252.567306
#
#    target_class
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
df.target_class.unique()
# Out:
# array([0, 1])

# %%
print(df.target_class.shape)
# Out:
# (17898,)

# %%
y = df.iloc[:,-1]
X = df.iloc[:,0:-1]
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size =0.2, random_state = 0, stratify=y)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (14318, 8)
# (14318,)
# (3580, 8)
# (3580,)

# %%
from sklearn.preprocessing import StandardScaler
standardScaler = StandardScaler()
X_train = standardScaler.fit_transform(X_train)
X_test = standardScaler.transform(X_test)

# %% [markdown]
# # Shallow
# > ### LogisticRegression
#
# > ### DecisionTreeRegressor

# %% [markdown]
# ## LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression(C=10,max_iter = 100, tol=.1,solver='sag')

# %%
# %%time
lr.fit(X_train, y_train)
# Out:
# CPU times: user 17.2 ms, sys: 2.01 ms, total: 19.2 ms
# Wall time: 19.5 ms
# LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='sag', tol=0.1, verbose=0,
#                    warm_start=False)

# %%
y_train_predict = lr.predict(X_train)
print ("Logistic Train Accuracy: %.3f" % accuracy_score(y_train,y_train_predict))
# Out:
# Logistic Train Accuracy: 0.977

# %%
y_test_predict = lr.predict_proba(X_test).argmax(axis = 1)
print("Logistic Test Accuracy: %.3f" % accuracy_score(y_test,y_test_predict))
# Out:
# Logistic Test Accuracy: 0.979

# %%
matrix = confusion_matrix(y_test, y_test_predict)
fig, ax = plt.subplots(figsize=(6, 4))
sns.heatmap(matrix, annot=True, cmap='Greens', fmt='d', ax=ax)
plt.title('Confusion Matrix')
plt.xlabel('Predicted label')
labels = np.unique(y_test)
plt.xticks(np.arange(len(labels))+0.5,labels)
plt.ylabel('True label')
plt.yticks(np.arange(len(labels))+0.5,labels)
plt.show()

# %% [markdown]
# ### Optimising Regularisation ('C')

# %%
from sklearn.model_selection import validation_curve

#define the values of C to test and then use validation_curve from sklearn to evaluate
parameter_range = [0.00001,0.0001,0.001,0.01,0.1,1,10,100]
train_scores, test_scores = validation_curve(estimator = lr, X=X_train, y=y_train, param_name ='C',param_range=parameter_range,cv=15)

# %%
#obtain the mean results from the samples
train_mean = np.mean(train_scores,axis=1)
test_mean = np.mean(test_scores,axis=1)

#plot the results
plt.plot(parameter_range,train_mean)
plt.plot(parameter_range,test_mean)
plt.xscale('log')

# %%
optimal_C = parameter_range[test_mean.argmax()]
print(optimal_C)
# Out:
# 100

# %% [markdown]
# ### The model is the best

# %% [markdown]
# ## DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
# %%time

tree = DecisionTreeRegressor()
tree.fit(X_train,y_train)
# Out:
# CPU times: user 121 ms, sys: 2.21 ms, total: 123 ms
# Wall time: 122 ms
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
# %%time
y_train_predict = tree.predict(X_train)
print ("tree Train Accuracy: %.3f" % accuracy_score(y_train,y_train_predict))
# Out:
# tree Train Accuracy: 1.000
# CPU times: user 4.13 ms, sys: 1.55 ms, total: 5.67 ms
# Wall time: 3.85 ms

# %%
# %%time
y_test_predict = tree.predict(X_test)
print("tree Test Accuracy: %.3f" % accuracy_score(y_test,y_test_predict))
# Out:
# tree Test Accuracy: 0.969
# CPU times: user 2.24 ms, sys: 1.5 ms, total: 3.75 ms
# Wall time: 2.2 ms

# %%
matrix = confusion_matrix(y_test, y_test_predict)
fig, ax = plt.subplots(figsize=(6, 4))
sns.heatmap(matrix, annot=True, cmap='Greens', fmt='d', ax=ax)
plt.title('Confusion Matrix')
plt.xlabel('Predicted label')
labels = np.unique(y_test)
plt.xticks(np.arange(len(labels))+0.5,labels)
plt.ylabel('True label')
plt.yticks(np.arange(len(labels))+0.5,labels)
plt.show()

# %% [markdown]
# # deep learning
# > #### MLP
#
# > #### CNN

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from keras.utils.vis_utils import plot_model
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## MLP

# %%
ann_model = Sequential()

ann_model.add(Dense(
        units = 4, kernel_initializer = 'uniform', activation = 'relu', input_dim = X_train.shape[1]))

ann_model.add(Dense(units = 64, kernel_initializer = 'uniform', activation = 'relu'))

ann_model.add(Dense(units = 32, kernel_initializer = 'uniform', activation = 'relu'))


ann_model.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

ann_model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
ann_model.summary()

image_name = 'plusarStars_ann_model.png'
plot_model(ann_model,to_file=image_name,show_shapes=True,show_layer_names=False,rankdir='TB')
plt.figure(figsize=(10,10))
img = plt.imread(image_name)
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# WARNING:tensorflow:From /Users/Tommy/opt/anaconda3/envs/python36/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 4)                 36
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                320
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 2,469
# Trainable params: 2,469
# Non-trainable params: 0
# _________________________________________________________________

# %%
ann_model.fit(X_train, y_train, batch_size=64, epochs=5)

hist = ann_model.fit(X_train, y_train,
                    batch_size=64,
                    epochs=5,
                    verbose=1,
                    validation_data=(X_test, y_test))

score = ann_model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# WARNING:tensorflow:From /Users/Tommy/opt/anaconda3/envs/python36/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/5
# 14318/14318 [==============================] - 1s 43us/step - loss: 0.3086 - accuracy: 0.9084
# Epoch 2/5
# 14318/14318 [==============================] - 0s 24us/step - loss: 0.1163 - accuracy: 0.9499
# Epoch 3/5
# 14318/14318 [==============================] - 0s 28us/step - loss: 0.0926 - accuracy: 0.9775
# Epoch 4/5
# 14318/14318 [==============================] - 0s 26us/step - loss: 0.0816 - accuracy: 0.9784
# Epoch 5/5
# 14318/14318 [==============================] - 0s 27us/step - loss: 0.0775 - accuracy: 0.9788
# Train on 14318 samples, validate on 3580 samples
# Epoch 1/5
# 14318/14318 [==============================] - 0s 31us/step - loss: 0.0758 - accuracy: 0.9796 - val_loss: 0.0732 - val_accuracy: 0.9796
# Epoch 2/5
# 14318/14318 [==============================] - 0s 26us/step - loss: 0.0741 - accuracy: 0.9792 - val_loss: 0.0729 - val_accuracy: 0.9793
# Epoch 3/5
# 14318/14318 [==============================] - 0s 28us/step - loss: 0.0730 - accuracy: 0.9795 - val_loss: 0.0699 - val_accuracy: 0.9804
# Epoch 4/5
# 14318/14318 [==============================] - 0s 27us/step - loss: 0.0728 - accuracy: 0.9796 - val_loss: 0.0689 - val_accuracy: 0.9804
# Epoch 5/5
# 14318/14318 [==============================] - 0s 26us/step - loss: 0.0721 - accuracy: 0.9794 - val_loss: 0.0712 - val_accuracy: 0.9793
# Test loss: 0.07115102408651533
# Test accuracy: 0.9793295860290527

# %%
plt.figure()
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')

plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')

image_name = 'plusarStars_ann_accuracy.png'
plt.savefig(image_name)

plt.show()

# %% [markdown]
# ## CNN

# %%
from keras.models import Sequential
from keras.layers import Input, Conv1D, Conv2D, BatchNormalization, Activation, MaxPooling1D, MaxPooling2D, Dropout, Flatten, Dense

# %%
X_train_resh = X_train[:, :, np.newaxis]
X_test_resh = X_test[:, :, np.newaxis]
print(X_train_resh.shape)
print(y_train.shape)

print(X_test_resh.shape)
print(y_test.shape)
# Out:
# (14318, 8, 1)
# (14318,)
# (3580, 8, 1)
# (3580,)

# %%
X_train_resh[0]
# Out:
# array([[-0.63397712],
#        [-0.9819066 ],
#        [-0.03306956],
#        [-0.07815054],
#        [-0.37014816],
#        [-0.63049162],
#        [ 0.7005112 ],
#        [ 0.48032751]])

# %%
#bn_axis = 3

cnn_model = Sequential()

cnn_model.add(Conv1D(filters = 16, kernel_size = 3, activation='tanh', input_shape=X_train_resh.shape[1:],padding = 'same', strides=1))
cnn_model.add(MaxPooling1D(pool_size=2))
cnn_model.add(Dropout(0.25))

cnn_model.add(Conv1D(filters = 32, kernel_size = 3,padding = 'same',activation='tanh',))
cnn_model.add(MaxPooling1D(pool_size=2))
cnn_model.add(Dropout(0.25))

cnn_model.add(Flatten())
cnn_model.add(Dense(1024, activation='tanh'))
cnn_model.add(Dropout(0.25))
        
cnn_model.add(Dense(1, activation='sigmoid'))
cnn_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])          

cnn_model.summary()

image_name = 'plusarStars_cnn_model.png'
plot_model(cnn_model,to_file=image_name,show_shapes=True,show_layer_names=False,rankdir='TB')
plt.figure(figsize=(20,20))
img = plt.imread(image_name)
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 8, 16)             64
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 4, 16)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 16)             0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 4, 32)             1568
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 2, 32)             0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2, 32)             0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1024)              66560
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 69,217
# Trainable params: 69,217
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_test_resh.shape
# Out:
# (3580, 8, 1)

# %%
hist = cnn_model.fit(X_train_resh, y_train,
                    batch_size=64,
                    epochs=10,
                    verbose=1,
                    validation_data=(X_test_resh, y_test)
                    )

score = cnn_model.evaluate(X_test_resh, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Train on 14318 samples, validate on 3580 samples
# Epoch 1/10
# 14318/14318 [==============================] - 2s 106us/step - loss: 0.1168 - accuracy: 0.9651 - val_loss: 0.0753 - val_accuracy: 0.9799
# Epoch 2/10
# 14318/14318 [==============================] - 1s 68us/step - loss: 0.0869 - accuracy: 0.9754 - val_loss: 0.0730 - val_accuracy: 0.9802
# Epoch 3/10
# 14318/14318 [==============================] - 1s 65us/step - loss: 0.0846 - accuracy: 0.9760 - val_loss: 0.0732 - val_accuracy: 0.9813
# Epoch 4/10
# 14318/14318 [==============================] - 1s 66us/step - loss: 0.0829 - accuracy: 0.9765 - val_loss: 0.0723 - val_accuracy: 0.9802
# Epoch 5/10
# 14318/14318 [==============================] - 1s 63us/step - loss: 0.0828 - accuracy: 0.9765 - val_loss: 0.0706 - val_accuracy: 0.9804
# Epoch 6/10
# 14318/14318 [==============================] - 1s 68us/step - loss: 0.0803 - accuracy: 0.9777 - val_loss: 0.0709 - val_accuracy: 0.9804
# Epoch 7/10
# 14318/14318 [==============================] - 1s 74us/step - loss: 0.0802 - accuracy: 0.9779 - val_loss: 0.0760 - val_accuracy: 0.9760
# Epoch 8/10
# 14318/14318 [==============================] - 1s 75us/step - loss: 0.0784 - accuracy: 0.9770 - val_loss: 0.0690 - val_accuracy: 0.9810
# Epoch 9/10
# 14318/14318 [==============================] - 1s 69us/step - loss: 0.0782 - accuracy: 0.9770 - val_loss: 0.0696 - val_accuracy: 0.9807
# Epoch 10/10
# 14318/14318 [==============================] - 1s 70us/step - loss: 0.0766 - accuracy: 0.9776 - val_loss: 0.0684 - val_accuracy: 0.9804
# Test loss: 0.06842485365754399
# Test accuracy: 0.9804469347000122

# %%
plt.figure()
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')

plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
